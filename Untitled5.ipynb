# %%
r=input("enter :")
v="aeiouAEIOU"
res=" "
for  i in r:
      if i in v:
          res+="*"
      else:
          res+=i
print(res)
# Out:
# enter : hello
#  h*ll*

# %%
s=input("enter :")
r=s[::-1]
if s==r:
    print("palin")
else:
    print("not")
# Out:
# enter : rar
# palin

# %%
import random
s=random.randint(1,20)
while True:
   g=int(input("enter a number"))
   if s>g:
        print("low")
   elif s<g:
        print("high")
   else:
        print("booyah")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 s=random.randint(1,20)
#       3 while True:
# ----> 4    g=int(input("enter a number"))
#       5    if s>g:
#       6         print("low")
#
# File c:\Users\rampr\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File c:\Users\rampr\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
l1=[1,2,3,4,5]
l2=[6,7,8,9,10]
l3=list(map(lambda x,y:x+y,l1,l2))
l=['pip','ram','program']
[i for i in l if i.startswith('p')]
[i for i in l1 if  i%2!=0]
# Out:
# 55
