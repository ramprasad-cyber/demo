# %%
r=input("enter :")
v="aeiouAEIOU"
res=" "
for  i in r:
      if i in v:
          res+="*"
      else:
          res+=i
print(res)
# Out:
# enter : hello
#  h*ll*

# %%
s=input("enter :")
r=s[::-1]
if s==r:
    print("palin")
else:
    print("not")
# Out:
# enter : rar
# palin

# %%
import random
s=random.randint(1,20)
while True:
    g=int(input())
    if s>g:
        print("low")
    elif s<g:
        print("high")
    else:
        print("booyah")
# Out:
#  19
# high
#  15
# high
#  10
# booyah
